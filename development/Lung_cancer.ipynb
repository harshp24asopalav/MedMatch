# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Dense,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
import matplotlib.pyplot as plt
import cv2 as cv
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
from keras.utils import to_categorical

import os

# %%
train_path_str = 'C:/Users/vishv/OneDrive/Documents/AIML_2/Project/data-collection/Lung_cancer/train'
val_path_str = 'C:/Users/vishv/OneDrive/Documents/AIML_2/Project/data-collection/Lung_cancer/valid'
test_path_str = 'C:/Users/vishv/OneDrive/Documents/AIML_2/Project/data-collection/Lung_cancer/test'

# %%
test_classes = os.listdir(test_path_str)

# %%
input_shape = (224,224,3)
num_classes = 4

trainGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    rotation_range = 10,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    shear_range = 0.2,
    zoom_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    dtype = 'float32'
)
valGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

testGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

# %%
train_data = trainGenertor.flow_from_directory(
    train_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

val_data = valGenertor.flow_from_directory(
    val_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

test_data = testGenertor.flow_from_directory(
    test_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
VGG16_model = VGG16(
    include_top = False,
    weights="imagenet",
    input_shape = input_shape
)
for layer in VGG16_model.layers :
  layer.trainable = False

# %%
from keras.metrics.confusion_metrics import activations
model = Sequential()
model.add(VGG16_model)
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(256,activation = 'relu'))
model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 512)        0
#  )
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 1024)              4719616
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 20,125,892
# Trainable params: 5,410,180
# Non-trainable params: 14,715,712
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy']
)
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ModelCheckpoint('model.h5',save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='logs')
]

# %%
results = model.fit(train_data,validation_data=val_data,epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 48s 1s/step - loss: 1.5070 - accuracy: 0.4307 - val_loss: 1.6926 - val_accuracy: 0.4444
# Epoch 2/100
# 39/39 [==============================] - 45s 1s/step - loss: 1.2480 - accuracy: 0.4796 - val_loss: 0.9812 - val_accuracy: 0.5000
# Epoch 3/100
# 39/39 [==============================] - 44s 1s/step - loss: 1.0984 - accuracy: 0.4992 - val_loss: 0.9129 - val_accuracy: 0.5000
# Epoch 4/100
# 39/39 [==============================] - 45s 1s/step - loss: 0.9777 - accuracy: 0.5481 - val_loss: 0.9797 - val_accuracy: 0.5278
# Epoch 5/100
# 39/39 [==============================] - 44s 1s/step - loss: 0.9394 - accuracy: 0.5563 - val_loss: 0.9922 - val_accuracy: 0.5000
# Epoch 6/100
# 39/39 [==============================] - 45s 1s/step - loss: 0.8599 - accuracy: 0.6166 - val_loss: 0.9193 - val_accuracy: 0.5417
# Epoch 7/100
# 39/39 [==============================] - 33s 831ms/step - loss: 0.2858 - accuracy: 0.8891 - val_loss: 0.6368 - val_accuracy: 0.8194
# Epoch 50/100
# 39/39 [==============================] - 33s 831ms/step - loss: 0.2937 - accuracy: 0.8891 - val_loss: 0.6927 - val_accuracy: 0.8194
# Epoch 51/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.2894 - accuracy: 0.9021 - val_loss: 0.5756 - val_accuracy: 0.8472
# Epoch 52/100
# 39/39 [==============================] - 33s 829ms/step - loss: 0.3299 - accuracy: 0.8646 - val_loss: 0.5329 - val_accuracy: 0.8194
# Epoch 53/100
# 39/39 [==============================] - 33s 833ms/step - loss: 0.3216 - accuracy: 0.8956 - val_loss: 0.4511 - val_accuracy: 0.8889
# Epoch 54/100
# 39/39 [==============================] - 33s 838ms/step - loss: 0.2803 - accuracy: 0.8923 - val_loss: 0.5746 - val_accuracy: 0.8611
# Epoch 55/100
# 39/39 [==============================] - 33s 837ms/step - loss: 0.2552 - accuracy: 0.9086 - val_loss: 0.7220 - val_accuracy: 0.8194
# Epoch 56/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.2822 - accuracy: 0.8907 - val_loss: 0.7532 - val_accuracy: 0.7917
# Epoch 57/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.2547 - accuracy: 0.9038 - val_loss: 0.5494 - val_accuracy: 0.8194
# Epoch 58/100
# 39/39 [==============================] - 33s 831ms/step - loss: 0.2251 - accuracy: 0.9152 - val_loss: 0.6195 - val_accuracy: 0.8194
# Epoch 59/100
# 39/39 [==============================] - 33s 832ms/step - loss: 0.3175 - accuracy: 0.8793 - val_loss: 0.5292 - val_accuracy: 0.8194
# Epoch 60/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.3017 - accuracy: 0.8891 - val_loss: 0.6354 - val_accuracy: 0.8333
# Epoch 61/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.3194 - accuracy: 0.8940 - val_loss: 0.5361 - val_accuracy: 0.8333
# Epoch 62/100
# 39/39 [==============================] - 33s 836ms/step - loss: 0.2857 - accuracy: 0.9005 - val_loss: 0.5899 - val_accuracy: 0.8611
# Epoch 63/100
# 39/39 [==============================] - 33s 833ms/step - loss: 0.2695 - accuracy: 0.9021 - val_loss: 0.6704 - val_accuracy: 0.8472
# Epoch 64/100
# 39/39 [==============================] - 33s 830ms/step - loss: 0.3698 - accuracy: 0.8891 - val_loss: 0.5979 - val_accuracy: 0.8333
# Epoch 65/100
# 39/39 [==============================] - 33s 832ms/step - loss: 0.2808 - accuracy: 0.9005 - val_loss: 0.5132 - val_accuracy: 0.8472
# Epoch 66/100
# 39/39 [==============================] - 33s 852ms/step - loss: 0.2686 - accuracy: 0.9119 - val_loss: 0.4685 - val_accuracy: 0.8611
# Epoch 67/100
# 39/39 [==============================] - 33s 831ms/step - loss: 0.2743 - accuracy: 0.9086 - val_loss: 0.4201 - val_accuracy: 0.8750
# Epoch 68/100
# 39/39 [==============================] - 33s 830ms/step - loss: 0.2487 - accuracy: 0.9086 - val_loss: 0.4541 - val_accuracy: 0.8472
# Epoch 69/100
# 39/39 [==============================] - 33s 831ms/step - loss: 0.2704 - accuracy: 0.9005 - val_loss: 0.4655 - val_accuracy: 0.8333
# Epoch 70/100
# 39/39 [==============================] - 33s 832ms/step - loss: 0.2621 - accuracy: 0.9038 - val_loss: 0.7045 - val_accuracy: 0.8472
# Epoch 71/100
# 39/39 [==============================] - 32s 829ms/step - loss: 0.2341 - accuracy: 0.9152 - val_loss: 0.7570 - val_accuracy: 0.8611
# Epoch 72/100
# 39/39 [==============================] - 32s 829ms/step - loss: 0.2394 - accuracy: 0.9038 - val_loss: 0.7233 - val_accuracy: 0.8333
# Epoch 73/100
# 39/39 [==============================] - 32s 827ms/step - loss: 0.2536 - accuracy: 0.9005 - val_loss: 0.6606 - val_accuracy: 0.8472
# Epoch 74/100
# 39/39 [==============================] - 32s 826ms/step - loss: 0.2709 - accuracy: 0.9038 - val_loss: 0.7666 - val_accuracy: 0.8472
# Epoch 75/100
# 39/39 [==============================] - 32s 828ms/step - loss: 0.2286 - accuracy: 0.9070 - val_loss: 0.6444 - val_accuracy: 0.8333
# Epoch 76/100
# 39/39 [==============================] - 33s 831ms/step - loss: 0.1901 - accuracy: 0.9250 - val_loss: 0.6469 - val_accuracy: 0.8194
# Epoch 77/100
# 39/39 [==============================] - 32s 830ms/step - loss: 0.2760 - accuracy: 0.9135 - val_loss: 0.6076 - val_accuracy: 0.8333
# Epoch 78/100
# 39/39 [==============================] - 32s 830ms/step - loss: 0.2704 - accuracy: 0.9086 - val_loss: 0.5897 - val_accuracy: 0.8333
# Epoch 79/100
# 39/39 [==============================] - 32s 829ms/step - loss: 0.2085 - accuracy: 0.9266 - val_loss: 0.7954 - val_accuracy: 0.8056
# Epoch 80/100
# 39/39 [==============================] - 32s 828ms/step - loss: 0.2030 - accuracy: 0.9315 - val_loss: 0.8171 - val_accuracy: 0.8194
# Epoch 81/100
# 39/39 [==============================] - 32s 825ms/step - loss: 0.2625 - accuracy: 0.9054 - val_loss: 0.6151 - val_accuracy: 0.8194
# Epoch 82/100
# 39/39 [==============================] - 33s 833ms/step - loss: 0.2228 - accuracy: 0.9119 - val_loss: 0.7838 - val_accuracy: 0.7917
# Epoch 83/100
# 39/39 [==============================] - 33s 836ms/step - loss: 0.3384 - accuracy: 0.8907 - val_loss: 0.6657 - val_accuracy: 0.8333
# Epoch 84/100
# 39/39 [==============================] - 33s 832ms/step - loss: 0.2269 - accuracy: 0.9201 - val_loss: 0.6379 - val_accuracy: 0.8472
# Epoch 85/100
# 39/39 [==============================] - 32s 827ms/step - loss: 0.2046 - accuracy: 0.9282 - val_loss: 0.5824 - val_accuracy: 0.8750
# Epoch 86/100
# 39/39 [==============================] - 32s 831ms/step - loss: 0.2282 - accuracy: 0.9282 - val_loss: 0.7198 - val_accuracy: 0.8333
# Epoch 87/100
# 39/39 [==============================] - 33s 833ms/step - loss: 0.2058 - accuracy: 0.9380 - val_loss: 0.7022 - val_accuracy: 0.8611
# Epoch 88/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.2563 - accuracy: 0.9070 - val_loss: 0.5818 - val_accuracy: 0.8750
# Epoch 89/100
# 39/39 [==============================] - 33s 832ms/step - loss: 0.1533 - accuracy: 0.9445 - val_loss: 0.7171 - val_accuracy: 0.8472
# Epoch 90/100
# 39/39 [==============================] - 32s 827ms/step - loss: 0.2067 - accuracy: 0.9201 - val_loss: 0.6868 - val_accuracy: 0.8611
# Epoch 91/100
# 39/39 [==============================] - 32s 830ms/step - loss: 0.2030 - accuracy: 0.9201 - val_loss: 0.7179 - val_accuracy: 0.8750
# Epoch 92/100
# 39/39 [==============================] - 33s 834ms/step - loss: 0.2215 - accuracy: 0.9299 - val_loss: 0.8304 - val_accuracy: 0.8056
# Epoch 93/100
# 39/39 [==============================] - 32s 826ms/step - loss: 0.2436 - accuracy: 0.9152 - val_loss: 0.5312 - val_accuracy: 0.8889
# Epoch 94/100
# 39/39 [==============================] - 32s 828ms/step - loss: 0.1959 - accuracy: 0.9250 - val_loss: 0.5687 - val_accuracy: 0.8889
# Epoch 95/100
# 39/39 [==============================] - 32s 828ms/step - loss: 0.2277 - accuracy: 0.9135 - val_loss: 0.5334 - val_accuracy: 0.8889
# Epoch 96/100
# 39/39 [==============================] - 32s 828ms/step - loss: 0.1963 - accuracy: 0.9347 - val_loss: 0.6577 - val_accuracy: 0.8611
# Epoch 97/100
# 39/39 [==============================] - 33s 832ms/step - loss: 0.1875 - accuracy: 0.9331 - val_loss: 0.6297 - val_accuracy: 0.8472
# Epoch 98/100
# 39/39 [==============================] - 32s 825ms/step - loss: 0.2402 - accuracy: 0.8972 - val_loss: 0.6626 - val_accuracy: 0.8194
# Epoch 99/100
# 39/39 [==============================] - 32s 827ms/step - loss: 0.1613 - accuracy: 0.9494 - val_loss: 0.6457 - val_accuracy: 0.8333
# Epoch 100/100
# 39/39 [==============================] - 33s 835ms/step - loss: 0.1882 - accuracy: 0.9315 - val_loss: 0.6471 - val_accuracy: 0.8611

# %%
loss, acc = model.evaluate(test_data,verbose = 1)
# Out:
# 20/20 [==============================] - 15s 746ms/step - loss: 0.5348 - accuracy: 0.8603

# %%
import seaborn as sns
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob , axis = 1)
true_label = test_data.classes
report = classification_report(true_label,predictions)
print(report)
# Out:
# 20/20 [==============================] - 15s 717ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86       120
#            1       0.78      0.84      0.81        51
#            2       0.98      0.94      0.96        54
#            3       0.97      0.72      0.83        90
#
#     accuracy                           0.86       315
#    macro avg       0.88      0.86      0.86       315
# weighted avg       0.87      0.86      0.86       315

# %%
conf_mat = confusion_matrix(true_label,predictions)
sns.heatmap(conf_mat ,fmt='g',annot = True , cmap='Blues' , xticklabels=test_classes , yticklabels = test_classes,)
plt.xlabel('Predictions')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.xticks(rotation = 45)
plt.show()

# %%
res = results.history
train_acc = res['accuracy']
val_accuracy = res['val_accuracy']
epochs = range(1, len(train_acc) + 1)

line1 = plt.plot(epochs, val_accuracy, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, train_acc, label = 'Training Accuracy')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
res = results.history
train_loss = res['loss']
val_loss = res['val_loss']
epochs = range(1, len(train_loss) + 1)

line1 = plt.plot(epochs, val_loss, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, train_loss, label = 'Training Loss')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
